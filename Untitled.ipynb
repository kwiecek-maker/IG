# %%
import os

# %%
for root, dirs, files in os.walk('database', topdown=False):
    for name in files:
        print(os.path.join(root, name))
# Out:
# database\Aleksandra Rogowiec\1\naprzod.wav
# database\Aleksandra Rogowiec\1\odbierz.wav
# database\Aleksandra Rogowiec\1\odrzuc.wav
# database\Aleksandra Rogowiec\1\odslon.wav
# database\Aleksandra Rogowiec\1\otworz.wav
# database\Aleksandra Rogowiec\1\start.wav
# database\Aleksandra Rogowiec\1\stop.wav
# database\Aleksandra Rogowiec\1\wlacz.wav
# database\Aleksandra Rogowiec\1\wstecz.wav
# database\Aleksandra Rogowiec\1\wylacz.wav
# database\Aleksandra Rogowiec\1\zamknij.wav
# database\Aleksandra Rogowiec\1\zaslon.wav
# database\Aleksandra Rogowiec\1\zaswiec.wav
# database\Aleksandra Rogowiec\1\zgas.wav
# database\Aleksandra_Pietrek\1\naprzod.wav
# database\Aleksandra_Pietrek\1\odbierz.wav
# database\Aleksandra_Pietrek\1\odrzuc.wav
# database\Aleksandra_Pietrek\1\odslon.wav
# database\Aleksandra_Pietrek\1\otworz.wav
# database\Aleksandra_Pietrek\1\start.wav
# database\Aleksandra_Pietrek\1\stop.wav
# database\Aleksandra_Pietrek\1\wlacz.wav
# database\Aleksandra_Pietrek\1\wstecz.wav
# ...
